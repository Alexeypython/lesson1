# %%
print "Hello, World"
# Out:
# Hello, World

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
plot([1,2,5,4,3,4,5,2])

# %% [markdown]
# ## Заголовок 1-го уровня
